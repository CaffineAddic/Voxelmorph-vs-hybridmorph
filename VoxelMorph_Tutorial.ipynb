# %% [markdown]
# # Introduction to VoxelMorph
# [Adrian Dalca](http://adalca.mit.edu) and Andrew Hoopes
# Introductory slides for this tutorial are [here](https://github.com/learn2reg/tutorials2019/blob/master/slides/Learn2reg_tutorial_unsupervided_AdrianDalca.pdf).
#
# This is a short tutorial to get you started with [VoxelMorph](https://github.com/voxelmorph/voxelmorph): deep-learning based registration.
#
# ### Outline
# - **Core concepts with MNIST**
# We will first learn to deal with data, building a model, training, registration and generalization
# - **More realistic complexity: Brain MRI (2D slices)**
# We will then show how these models work for 2d slices of brain scans, presenting a more complex scenario
# - **Realistic 3D Brain MRI**
# We will illustrate full 3D registration
# - **Advances topics**
# Finally, we close with more advanced topics, including diffeomorphisms and fine-tuning deformations

# %% [markdown]
# Throughout this tutorial we assume that the images have been rigidly aligned in a (roughly) similar space.
# Rigid alignment is also possible with VoxelMorph, but it's not our focus here.  A separate tutorial is being designed for that

# %% [markdown]
# ### References
# [VoxelMorph at TMI](https://arxiv.org/abs/1809.05231)
# [Diffeomorphic VoxelMorph at MedIA](https://arxiv.org/abs/1903.03545)
# [Neurite Library](https://github.com/adalca/neuron) - [CVPR](http://arxiv.org/abs/1903.03148)

# %% [markdown]
# ---

# %% [markdown]
# # Preamble
# ## Setup of environment

# %%
# # install voxelmorph, which will also install dependencies: neurite and pystrum
# !pip install voxelmorph

# %% [markdown]
# We'll start with some common imports

# %%
# imports
import os, sys

# third party imports
import numpy as np
import tensorflow as tf
# assert tf.__version__.startswith('2.'), 'This tutorial assumes Tensorflow 2.0+'
# Out:
# 2023-01-25 11:05:00.359745: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-25 11:05:00.612688: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-01-25 11:05:01.262989: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.0/lib64:/home/saumya/Enter/envs/tf/lib/
# 2023-01-25 11:05:01.263101: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.0/lib64:/home/saumya/Enter/envs/tf/lib/
# 2023-01-25 11:05:01.263113: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# Next, we import two packages that will help us
# - [voxelmorph](http://voxelmorph.mit.edu) is a deep-learning based registration library
# - [neurite](https://github.com/adalca/neurite) is a library for medical image analysis with tensorflow

# %%
# local imports
import voxelmorph as vxm
import neurite as ne

# %% [markdown]
# ---

# %% [markdown]
# # Data

# %% [markdown]
# We're going to start by registering 2D MNIST digits, and then move on to medical data later. If the data is small (like 2D MNIST), you can often load it in memory, which enables for faster training and testing. If the data is large (large 3D scans), we will likely need to load the scans on demand. More on this later.
#
# First, we're going to **load the data**. Luckily, MNIST comes with the keras framework, so we can just load it here

# %%
# # You should most often have this import together with all other imports at the top, 
# # but we include here here explicitly to show where data comes from
# from tensorflow.keras.datasets import mnist

# %%
# # load MNIST data. 
# # `mnist.load_data()` already splits our data into train and test.  
# (x_train_load, y_train_load), (x_test_load, y_test_load) = mnist.load_data()

# digit_sel = 5

# # extract only instances of the digit 5
# x_train = x_train_load[y_train_load==digit_sel, ...]
# y_train = y_train_load[y_train_load==digit_sel]
# x_test = x_test_load[y_test_load==digit_sel, ...]
# y_test = y_test_load[y_test_load==digit_sel]

# # let's get some shapes to understand what we loaded.
# print('shape of x_train: {}, y_train: {}'.format(x_train.shape, y_train.shape))

# %% [markdown]
# **ML detour**: separating your data in *only* train/test **often leads to problems**
# You wouldn't want to iteratively (A) build a model, (B) train on training data, and (C) test on test data
# Doing so will **overfit to you test set** (because you will have adapted your algorithm to your test data). It's a common mistakes in ML submissions.
#
# We will split the 'training' into 'train/validate' data, and keep the test set for later
# And will only look at the test data at the very end (once we're ready to submit the paper!)

# %%
# nb_val = 1000  # keep 1,000 subjects for validation
# x_val = x_train[-nb_val:, ...]  # this indexing means "the last nb_val entries" of the zeroth axis
# y_val = y_train[-nb_val:]
# x_train = x_train[:-nb_val, ...]
# y_train = y_train[:-nb_val]

# %% [markdown]
# ### Visualize Data

# %% [markdown]
# When we are done loading, it's always great to visualize the data
# Here, we use some tools from a package called `neurite`, which uses matplotlib
# You could use matplotlib as well directly, but it would just be a bit messier
# and here we want to illustrate the main concepts.

# %%
# nb_vis = 5

# # choose nb_vis sample indexes
# idx = np.random.choice(x_train.shape[0], nb_vis, replace=False)
# example_digits = [f for f in x_train[idx, ...]]

# # plot
# ne.plot.slices(example_digits, cmaps=['gray'], do_colorbars=True);

# %% [markdown]
# Looks good!
#
# However, luckily we included a **colorbar**, which shows us that the data is in [0, 255].
# In neural networks it's often great to work in the ranges of [0, 1] or [-1, 1] or around there.
# Let's fix this.
#
# In general, you should always plot your data with colorbars, which helps you catch issues before training

# %%
# # fix data
# x_train = x_train.astype('float')/255
# x_val = x_val.astype('float')/255
# x_test = x_test.astype('float')/255

# # verify
# print('training maximum value', x_train.max())

# %%
# # re-visualize
# example_digits = [f for f in x_train[idx, ...]]
# ne.plot.slices(example_digits, cmaps=['gray'], do_colorbars=True);

# %% [markdown]
# One last change. Later on, we'll see that some of the most popular models like to have inputs that are sized as multiples of 2^N for N being the number of layers. Here, we force our images to be size 32 (2x 2^4).

# %%
# pad_amount = ((0, 0), (2,2), (2,2))

# # fix data
# x_train = np.pad(x_train, pad_amount, 'constant')
# x_val = np.pad(x_val, pad_amount, 'constant')
# x_test = np.pad(x_test, pad_amount, 'constant')

# # verify
# print('shape of training data', x_train.shape)

# %% [markdown]
# ---

# %% [markdown]
# # CNN Model

# %% [markdown]
# Given two images (which we call *moving* and *fixed*), our goal is to find the deformation between them. In learning-based methods, we use a network that takes in two images $m$ ("moving") and $f$ ("fixed") (e.g. MNIST digits of size 32x32) and outputs a dense deformation $\phi$ (e.g. size 32x32x2, because at each pixel we want a vector telling us where to go). Intuitively, this deformation $\phi$ gives us the correspondances between the images, and tells us how to moving the moving image to match up with the fixed image.
#
# **Note**: Registration also includes (or refers to) affine transforms, but we ignore that here.
#
# The [VoxelMorph](http://voxelmorph.mit.edu) library provides a `VxmDense` model class for building dense deformation networks. We will discuss this class later on, but for tutorial sake, we'll start by building this model from scratch in order to demonstrate the individual components of the network. First, we're going to abstract the UNet and with the `vxm.networks.Unet()` model.

# %%
# # configure unet input shape (concatenation of moving and fixed images)
# ndim = 2
# unet_input_features = 2
# inshape = (*x_train.shape[1:], unet_input_features)

# # configure unet features 
# nb_features = [
#     [32, 32, 32, 32],         # encoder features
#     [32, 32, 32, 32, 32, 16]  # decoder features
# ]

# # build model
# unet = vxm.networks.Unet(inshape=inshape, nb_features=nb_features)

# %% [markdown]
# Let's explore the model bit...

# %%
# print('input shape: ', unet.input.shape)
# print('output shape:', unet.output.shape)

# %% [markdown]
# Now we need to make sure the final output has 2 features, representing the deformation at each voxel.

# %%
# # transform the results into a flow field.
# disp_tensor = tf.keras.layers.Conv2D(ndim, kernel_size=3, padding='same', name='disp')(unet.output)

# # check tensor shape
# print('displacement tensor:', disp_tensor.shape)

# # using keras, we can easily form new models via tensor pointers
# def_model = tf.keras.models.Model(unet.inputs, disp_tensor)

# %% [markdown]
# The deformation model `def_model` will now *share layers* with the UNet model, so if we change layer weights in `unet`, they change in `def_model`.

# %% [markdown]
# ### Loss

# %% [markdown]
# Given that the displacement $\phi$ is output from the network,
# we need to figure out a loss to tell if it makes sense

# %% [markdown]
# In a **supervised setting** we would have ground truth deformations $\phi_{gt}$,
# and we could use a supervised loss like MSE $= \| \phi - \phi_{gt} \|$

# %% [markdown]
# The main idea in **unsupervised registration** is to use loss inspired by classical registration
#
# Without supervision, how do we know this deformation is good?
# (1) make sure that $m \circ \phi$ ($m$ warped by $\phi$) is close to $f$
# (2) regularize $\phi$ (often meaning make sure it's smooth)

# %% [markdown]
# To achieve (1), we need to *warp* input image $m$. To do this, we use a spatial transformation network layer, which essentially does linear interpolation.

# %%
# # build transformer layer
# spatial_transformer = vxm.layers.SpatialTransformer(name='transformer')

# # extract the first frame (i.e. the "moving" image) from unet input tensor
# moving_image = tf.expand_dims(unet.input[..., 0], axis=-1)

# # warp the moving image with the transformer
# moved_image_tensor = spatial_transformer([moving_image, disp_tensor])

# %% [markdown]
# To make sure the moved image is close to the fixed image, and to achieve smoothness loss of $\phi$ in (2), we will want these two as outputs from the full model.

# %%
# outputs = [moved_image_tensor, disp_tensor]
# vxm_model = tf.keras.models.Model(inputs=unet.inputs, outputs=outputs)

# %% [markdown]
# The model we just created represents the standard, dense VoxelMorph archetecture, with a UNet component, displacement field, and final spatial transformer layer. However, you don't have to build this model from scratch every time - the VoxelMorph library provides a highly customizable `VxmDense` model class that encompasses this archetecture.
#
# From now on in the tutorial, we will be using `VxmDense` class to build models, so let's rebuild the equivolent network.

# %%
# # build model using VxmDense
# inshape = x_train.shape[1:]
# vxm_model = vxm.networks.VxmDense(inshape, nb_features, int_steps=0)

# %% [markdown]
# The `int_steps=0` option disables diffeomorphism, which will be covered in a more advanced tutorial.
#
# It's worth noting that the `VxmDense` model is automatically configured with two input tensors (moving and fixed inputs) instead of one. The input shape parameter should not contain any feature information, which can be set via the optional `src_feats` and `trg_feats` parameters.
#
# Let's take one final look at the model.

# %%
# print('input shape: ', ', '.join([str(t.shape) for t in vxm_model.inputs]))
# print('output shape:', ', '.join([str(t.shape) for t in vxm_model.outputs]))

# %% [markdown]
# Now that've learned how to easily build our networks, let's define the actual loss. The way keras works, we need to define a loss for each output.
# The first loss is easy, it's simply MSE between the warped image $m \circ \phi$.
# For the second, we will use a spatial gradient of the displacement.
# We won't code this from scratch here, but we'll use the `voxelmorph` implementation.

# %%
# # voxelmorph has a variety of custom loss classes
# losses = [vxm.losses.MSE().loss, vxm.losses.Grad('l2').loss]

# # usually, we have to balance the two losses by a hyper-parameter
# lambda_param = 0.05
# loss_weights = [1, lambda_param]

# %% [markdown]
# Finally, we can compile the model.
# This sets up the model for training, by associating the model with a loss and an optimizer

# %%
# vxm_model.compile(optimizer='Adam', loss=losses, loss_weights=loss_weights)

# %% [markdown]
# # Train Model

# %% [markdown]
# To train, we need to make sure the data is in the right format and fed to the model the way we want it keras models can be trained with `model.fit`, which requires all the data to be in a big array, or `model.fit_generator`, which requires a python generator that gives you batches of data.
#
# Let's code a simple data generator based on the MNIST data.

# %%
def vxm_data_generator(x_data, batch_size=1):
    """
    Generator that takes in data of size [N, H, W], and yields data for
    our custom vxm model. Note that we need to provide numpy data for each
    input, and each output.

    inputs:  moving [bs, H, W, 1], fixed image [bs, H, W, 1]
    outputs: moved image [bs, H, W, 1], zero-gradient [bs, H, W, 2]
    """

    # preliminary sizing
    vol_shape = x_data.shape[1:] # extract data shape
    ndims = len(vol_shape)
    
    # prepare a zero array the size of the deformation
    # we'll explain this below
    zero_phi = np.zeros([batch_size, *vol_shape, ndims])
    
    while True:
        # prepare inputs:
        # images need to be of the size [batch_size, H, W, 1]
        idx1 = np.random.randint(0, x_data.shape[0], size=batch_size)
        moving_images = x_data[idx1, ..., np.newaxis]
        idx2 = np.random.randint(0, x_data.shape[0], size=batch_size)
        fixed_images = x_data[idx2, ..., np.newaxis]
        inputs = [moving_images, fixed_images]
        
        # prepare outputs (the 'true' moved image):
        # of course, we don't have this, but we know we want to compare 
        # the resulting moved image with the fixed image. 
        # we also wish to penalize the deformation field. 
        outputs = [fixed_images, zero_phi]
        
        yield (inputs, outputs)

# %%
# # let's test it
# train_generator = vxm_data_generator(x_train)
# in_sample, out_sample = next(train_generator)

# # visualize
# images = [img[0, :, :, 0] for img in in_sample + out_sample] 
# titles = ['moving', 'fixed', 'moved ground-truth (fixed)', 'zeros']
# ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %%
# nb_epochs = 10
# steps_per_epoch = 100
# hist = vxm_model.fit_generator(train_generator, epochs=nb_epochs, steps_per_epoch=steps_per_epoch, verbose=2);

# %% [markdown]
# It's always a good idea to visualize the loss, not just read off the numbers. This will give us a better idea of whether it's converged, etc. Tensorflow offers a powerful interactive system for visualizing called tensorboard. For this short tutorial, we will simply plot the loss.

# %%
import matplotlib.pyplot as plt

def plot_history(hist, loss_name='loss'):
    # Simple function to plot training history.
    plt.figure()
    plt.plot(hist.epoch, hist.history[loss_name], '.-')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

# %% [markdown]
# Clearly, this is not converged, and you should run it to convergence, but for the purposes of this tutorial, we'll move on.

# %% [markdown]
# # Registration

# %% [markdown]
# With pair-wise optimization methods (like most classical methods), to register a new pair you would need to optimize a deformation field.
#
# With learning based registration, we simply evaluate the network for a new input pair

# %%
# # let's get some data
# val_generator = vxm_data_generator(x_val, batch_size = 1)
# val_input, _ = next(val_generator)

# %% [markdown]
# *Registration*: `predict()` essentially executes the network given an input.

# %%
# val_pred = vxm_model.predict(val_input)

# %% [markdown]
# and that's it!
#
# Even though this is on MNIST only, let's see how long this takes

# %%
# # %timeit is a 'jupyter magic' that times the given line over several runs
# %timeit vxm_model.predict(val_input)

# %% [markdown]
# ~3 ms per registration is quite fast, even for MNIST. Let's visualize the results.

# %%
# # visualize
# images = [img[0, :, :, 0] for img in val_input + val_pred] 
# titles = ['moving', 'fixed', 'moved', 'flow']
# ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %% [markdown]
# Let's visualize the flow a bit better.

# %%
# ne.plot.flow([val_pred[1].squeeze()], width=5);

# %% [markdown]
# # Generalization
# How do learning-based methods generalize beyond training distribution ?

# %% [markdown]
# An important caveat to learning-based registration is that they will, in general, only register samples fromt he distribution they've been trained from.
#
# So, what happens if we register two 7's?

# %%
# # extract only instances of the digit 7
# x_sevens = x_train_load[y_train_load==7, ...].astype('float') / 255
# x_sevens = np.pad(x_sevens, pad_amount, 'constant')

# # predict
# seven_generator = vxm_data_generator(x_sevens, batch_size=1)
# seven_sample, _ = next(seven_generator)
# seven_pred = vxm_model.predict(seven_sample)

# %%
# # visualize
# images = [img[0, :, :, 0] for img in seven_sample + seven_pred] 
# titles = ['moving', 'fixed', 'moved', 'flow']
# ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %% [markdown]
# Interesting - it still works! So it **generalized beyond what we expected**. Why? Locally, parts of the 7s look similar to the 5s, so the  registration algorithm still tries to match local neighborhoods.
#
# Let's try a different variation. What if we just modify the (original) set, but multiplied the intensities by a factor?

# %%
# factor = 5
# val_pred = vxm_model.predict([f * factor for f in val_input])

# # visualizeb
# images = [img[0, :, :, 0] for img in val_input + val_pred] 
# titles = ['moving', 'fixed', 'moved', 'flow']
# ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %% [markdown]
# This broke down! Why? In this case, the network has never seen even parts of this image.
#
# Understanding when the network generalizes and when it does not is very important, and still a part of active research.

# %% [markdown]
# # Registration of Brain MRI

# %% [markdown]
# We will now register slightly more realistic data - MRIs of the brain.  To be able to train and easily register during this tutorial, we will first extract the middle slice of brain scans.
#
# Note that because this task does not capture deformations in the third dimensions, certain  correspondances are not exactly possible.  Nonetheless, this exercise will illustrate registration with more realistic complex images.
#
# The brains have been intensity-normalized affinely aligned, and skull-stripped with FreeSurfer, to enable focusing on deformable registration.

# %%
# # download MRI tutorial data
# !wget https://surfer.nmr.mgh.harvard.edu/pub/data/voxelmorph/tutorial_data.tar.gz -O data.tar.gz
# !tar -xzvf data.tar.gz

# %%
npz = np.load('tutorial_data.npz')
x_train = npz['train']
x_val = npz['validate']

# the 208 volumes are of size 160x192
vol_shape = x_train.shape[1:]
print('train shape:', x_train.shape)
# Out:
# train shape: (208, 192, 160)

# %% [markdown]
# Let's take a look at some of the data.

# %%
# extract some brains
nb_vis = 5
idx = np.random.randint(0, x_train.shape[0], [5,])
example_digits = [f for f in x_train[idx, ...]]

# visualize
ne.plot.slices(example_digits, cmaps=['gray'], do_colorbars=True);

# %%
nb_features = [
    [16, 32, 32, 32],
    [32, 32, 32, 32, 32, 16, 16]
]

# %% [markdown]
# ### Model

# %% [markdown]
# As with MNIST, let's create a standard VoxelMorph model trained with MSE and spatial smoothing losses.

# %%
# unet
vxm_model = vxm.networks.VxmDense(vol_shape, nb_features, int_steps=0)

# losses and loss weights
losses = ['mse', vxm.losses.Grad('l2').loss]
loss_weights = [1, 0.01]
# Out:
# 2023-01-25 11:05:04.358106: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-25 11:05:05.892229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15787 MB memory:  -> device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# 2023-01-25 11:05:05.893273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 14322 MB memory:  -> device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 0000:af:00.0, compute capability: 7.0

# %% [markdown]
# From experimentation, we have found the Adam optimizer learning rate of `1e-4` performs better than `1e-3` for this problem.

# %%
vxm_model.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-4), loss=losses, loss_weights=loss_weights)
# Out:
# /home/saumya/Enter/envs/tf/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# Luckily, we can use the same generator as before, since we're using the same format. Let's test it first.

# %%
# let's test it
train_generator = vxm_data_generator(x_train, batch_size=1)
in_sample, out_sample = next(train_generator)

# visualize
images = [img[0, :, :, 0] for img in in_sample + out_sample]
titles = ['moving', 'fixed', 'moved ground-truth (fixed)', 'zeros']
ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %% [markdown]
# Looks good, time to **train the model**

# %%
hist = vxm_model.fit_generator(train_generator, epochs=1500, steps_per_epoch=100, verbose=2);
# Out:
# Epoch 1/1500
# /tmp/ipykernel_262260/1874730861.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = vxm_model.fit_generator(train_generator, epochs=1500, steps_per_epoch=100, verbose=2);
# 2023-01-25 11:05:11.494663: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 100/100 - 7s - loss: 0.0068 - vxm_dense_transformer_loss: 0.0068 - vxm_dense_flow_loss: 3.8609e-05 - 7s/epoch - 66ms/step
# Epoch 2/1500
# 100/100 - 2s - loss: 0.0067 - vxm_dense_transformer_loss: 0.0067 - vxm_dense_flow_loss: 2.0913e-04 - 2s/epoch - 18ms/step
# Epoch 3/1500
# 100/100 - 2s - loss: 0.0058 - vxm_dense_transformer_loss: 0.0057 - vxm_dense_flow_loss: 0.0136 - 2s/epoch - 18ms/step
# Epoch 4/1500
# 100/100 - 2s - loss: 0.0043 - vxm_dense_transformer_loss: 0.0039 - vxm_dense_flow_loss: 0.0356 - 2s/epoch - 18ms/step
# Epoch 5/1500
# 100/100 - 2s - loss: 0.0039 - vxm_dense_transformer_loss: 0.0035 - vxm_dense_flow_loss: 0.0444 - 2s/epoch - 18ms/step
# Epoch 6/1500
# 100/100 - 2s - loss: 0.0036 - vxm_dense_transformer_loss: 0.0031 - vxm_dense_flow_loss: 0.0498 - 2s/epoch - 18ms/step
# Epoch 7/1500
# 100/100 - 2s - loss: 0.0039 - vxm_dense_transformer_loss: 0.0034 - vxm_dense_flow_loss: 0.0535 - 2s/epoch - 19ms/step
# Epoch 8/1500
# 100/100 - 2s - loss: 0.0035 - vxm_dense_transformer_loss: 0.0029 - vxm_dense_flow_loss: 0.0590 - 2s/epoch - 19ms/step
# Epoch 9/1500
# 100/100 - 2s - loss: 0.0034 - vxm_dense_transformer_loss: 0.0028 - vxm_dense_flow_loss: 0.0574 - 2s/epoch - 19ms/step
# Epoch 10/1500
# 100/100 - 2s - loss: 0.0033 - vxm_dense_transformer_loss: 0.0027 - vxm_dense_flow_loss: 0.0594 - 2s/epoch - 19ms/step
# Epoch 11/1500
# 100/100 - 2s - loss: 0.0031 - vxm_dense_transformer_loss: 0.0025 - vxm_dense_flow_loss: 0.0593 - 2s/epoch - 19ms/step
# Epoch 12/1500
# 100/100 - 2s - loss: 0.0033 - vxm_dense_transformer_loss: 0.0027 - vxm_dense_flow_loss: 0.0644 - 2s/epoch - 19ms/step
# Epoch 13/1500
# 100/100 - 2s - loss: 0.0029 - vxm_dense_transformer_loss: 0.0023 - vxm_dense_flow_loss: 0.0594 - 2s/epoch - 19ms/step
# Epoch 14/1500
# 100/100 - 2s - loss: 0.0030 - vxm_dense_transformer_loss: 0.0024 - vxm_dense_flow_loss: 0.0613 - 2s/epoch - 19ms/step
# Epoch 15/1500
# 100/100 - 2s - loss: 0.0030 - vxm_dense_transformer_loss: 0.0024 - vxm_dense_flow_loss: 0.0646 - 2s/epoch - 18ms/step
# Epoch 16/1500
# 100/100 - 2s - loss: 0.0029 - vxm_dense_transformer_loss: 0.0023 - vxm_dense_flow_loss: 0.0633 - 2s/epoch - 18ms/step
# Epoch 17/1500
# 100/100 - 2s - loss: 0.0031 - vxm_dense_transformer_loss: 0.0024 - vxm_dense_flow_loss: 0.0669 - 2s/epoch - 19ms/step
# Epoch 18/1500
# 100/100 - 2s - loss: 0.0030 - vxm_dense_transformer_loss: 0.0024 - vxm_dense_flow_loss: 0.0674 - 2s/epoch - 19ms/step
# Epoch 19/1500
# 100/100 - 2s - loss: 0.0028 - vxm_dense_transformer_loss: 0.0021 - vxm_dense_flow_loss: 0.0643 - 2s/epoch - 18ms/step
# Epoch 20/1500
# 100/100 - 2s - loss: 0.0028 - vxm_dense_transformer_loss: 0.0021 - vxm_dense_flow_loss: 0.0669 - 2s/epoch - 19ms/step
# Epoch 21/1500
# 100/100 - 2s - loss: 0.0028 - vxm_dense_transformer_loss: 0.0022 - vxm_dense_flow_loss: 0.0673 - 2s/epoch - 18ms/step
# Epoch 22/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0021 - vxm_dense_flow_loss: 0.0666 - 2s/epoch - 19ms/step
# Epoch 23/1500
# 100/100 - 2s - loss: 0.0029 - vxm_dense_transformer_loss: 0.0023 - vxm_dense_flow_loss: 0.0663 - 2s/epoch - 19ms/step
# Epoch 24/1500
# 100/100 - 2s - loss: 0.0028 - vxm_dense_transformer_loss: 0.0021 - vxm_dense_flow_loss: 0.0671 - 2s/epoch - 18ms/step
# Epoch 25/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0683 - 2s/epoch - 19ms/step
# Epoch 26/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0681 - 2s/epoch - 18ms/step
# Epoch 27/1500
# 100/100 - 2s - loss: 0.0028 - vxm_dense_transformer_loss: 0.0021 - vxm_dense_flow_loss: 0.0693 - 2s/epoch - 18ms/step
# Epoch 28/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0678 - 2s/epoch - 19ms/step
# Epoch 29/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0670 - 2s/epoch - 18ms/step
# Epoch 30/1500
# 100/100 - 2s - loss: 0.0028 - vxm_dense_transformer_loss: 0.0021 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 18ms/step
# Epoch 31/1500
# 100/100 - 2s - loss: 0.0029 - vxm_dense_transformer_loss: 0.0022 - vxm_dense_flow_loss: 0.0740 - 2s/epoch - 18ms/step
# Epoch 32/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0662 - 2s/epoch - 18ms/step
# Epoch 33/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0661 - 2s/epoch - 18ms/step
# Epoch 34/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0693 - 2s/epoch - 19ms/step
# Epoch 35/1500
# 100/100 - 2s - loss: 0.0029 - vxm_dense_transformer_loss: 0.0022 - vxm_dense_flow_loss: 0.0721 - 2s/epoch - 18ms/step
# Epoch 36/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 18ms/step
# Epoch 37/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 18ms/step
# Epoch 38/1500
# 100/100 - 2s - loss: 0.0028 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0737 - 2s/epoch - 18ms/step
# Epoch 39/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0671 - 2s/epoch - 18ms/step
# Epoch 40/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0653 - 2s/epoch - 18ms/step
# Epoch 41/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0715 - 2s/epoch - 18ms/step
# Epoch 42/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0689 - 2s/epoch - 19ms/step
# Epoch 43/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0682 - 2s/epoch - 18ms/step
# Epoch 44/1500
# 100/100 - 2s - loss: 0.0028 - vxm_dense_transformer_loss: 0.0021 - vxm_dense_flow_loss: 0.0734 - 2s/epoch - 18ms/step
# Epoch 45/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0690 - 2s/epoch - 19ms/step
# Epoch 46/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0714 - 2s/epoch - 18ms/step
# Epoch 47/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 18ms/step
# Epoch 48/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0697 - 2s/epoch - 18ms/step
# Epoch 49/1500
# 100/100 - 2s - loss: 0.0028 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0753 - 2s/epoch - 18ms/step
# Epoch 50/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 18ms/step
# Epoch 51/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 18ms/step
# Epoch 52/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0679 - 2s/epoch - 18ms/step
# Epoch 53/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0681 - 2s/epoch - 18ms/step
# Epoch 54/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0690 - 2s/epoch - 17ms/step
# Epoch 55/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0673 - 2s/epoch - 18ms/step
# Epoch 56/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0713 - 2s/epoch - 18ms/step
# Epoch 57/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0661 - 2s/epoch - 18ms/step
# Epoch 58/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0713 - 2s/epoch - 19ms/step
# Epoch 59/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0724 - 2s/epoch - 19ms/step
# Epoch 60/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0672 - 2s/epoch - 19ms/step
# Epoch 61/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0020 - vxm_dense_flow_loss: 0.0755 - 2s/epoch - 19ms/step
# Epoch 62/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 18ms/step
# Epoch 63/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0705 - 2s/epoch - 19ms/step
# Epoch 64/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0681 - 2s/epoch - 18ms/step
# Epoch 65/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0743 - 2s/epoch - 19ms/step
# Epoch 66/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0719 - 2s/epoch - 19ms/step
# Epoch 67/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0725 - 2s/epoch - 18ms/step
# Epoch 68/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0723 - 2s/epoch - 18ms/step
# Epoch 69/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0686 - 2s/epoch - 19ms/step
# Epoch 70/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 19ms/step
# Epoch 71/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0674 - 2s/epoch - 18ms/step
# Epoch 72/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 18ms/step
# Epoch 73/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0679 - 2s/epoch - 18ms/step
# Epoch 74/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0714 - 2s/epoch - 19ms/step
# Epoch 75/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0731 - 2s/epoch - 19ms/step
# Epoch 76/1500
# 100/100 - 2s - loss: 0.0027 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0758 - 2s/epoch - 18ms/step
# Epoch 77/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0675 - 2s/epoch - 19ms/step
# Epoch 78/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0715 - 2s/epoch - 18ms/step
# Epoch 79/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0676 - 2s/epoch - 18ms/step
# Epoch 80/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0670 - 2s/epoch - 18ms/step
# Epoch 81/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0732 - 2s/epoch - 18ms/step
# Epoch 82/1500
# 100/100 - 2s - loss: 0.0025 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0751 - 2s/epoch - 18ms/step
# Epoch 83/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0714 - 2s/epoch - 18ms/step
# Epoch 84/1500
# 100/100 - 2s - loss: 0.0026 - vxm_dense_transformer_loss: 0.0018 - vxm_dense_flow_loss: 0.0741 - 2s/epoch - 19ms/step
# Epoch 85/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 19ms/step
# Epoch 86/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0714 - 2s/epoch - 18ms/step
# Epoch 87/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0685 - 2s/epoch - 18ms/step
# Epoch 88/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0697 - 2s/epoch - 19ms/step
# Epoch 89/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0687 - 2s/epoch - 19ms/step
# Epoch 90/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0751 - 2s/epoch - 18ms/step
# Epoch 91/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0677 - 2s/epoch - 18ms/step
# Epoch 92/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0705 - 2s/epoch - 18ms/step
# Epoch 93/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0684 - 2s/epoch - 19ms/step
# Epoch 94/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0711 - 2s/epoch - 19ms/step
# Epoch 95/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 19ms/step
# Epoch 96/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0681 - 2s/epoch - 19ms/step
# Epoch 97/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0735 - 2s/epoch - 19ms/step
# Epoch 98/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0712 - 2s/epoch - 19ms/step
# Epoch 99/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0691 - 2s/epoch - 18ms/step
# Epoch 100/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0670 - 2s/epoch - 19ms/step
# Epoch 101/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0721 - 2s/epoch - 20ms/step
# Epoch 102/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 19ms/step
# Epoch 103/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0711 - 2s/epoch - 19ms/step
# Epoch 104/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0723 - 2s/epoch - 19ms/step
# Epoch 105/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0660 - 2s/epoch - 20ms/step
# Epoch 106/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0721 - 2s/epoch - 18ms/step
# Epoch 107/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0729 - 2s/epoch - 19ms/step
# Epoch 108/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 19ms/step
# Epoch 109/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0736 - 2s/epoch - 18ms/step
# Epoch 110/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0686 - 2s/epoch - 18ms/step
# Epoch 111/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0683 - 2s/epoch - 18ms/step
# Epoch 112/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0746 - 2s/epoch - 18ms/step
# Epoch 113/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 18ms/step
# Epoch 114/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 19ms/step
# Epoch 115/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0750 - 2s/epoch - 19ms/step
# Epoch 116/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0670 - 2s/epoch - 18ms/step
# Epoch 117/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0711 - 2s/epoch - 18ms/step
# Epoch 118/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0693 - 2s/epoch - 19ms/step
# Epoch 119/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0689 - 2s/epoch - 18ms/step
# Epoch 120/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0700 - 2s/epoch - 18ms/step
# Epoch 121/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 19ms/step
# Epoch 122/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0671 - 2s/epoch - 19ms/step
# Epoch 123/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0711 - 2s/epoch - 18ms/step
# Epoch 124/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0704 - 2s/epoch - 18ms/step
# Epoch 125/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0688 - 2s/epoch - 19ms/step
# Epoch 126/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0700 - 2s/epoch - 19ms/step
# Epoch 127/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0743 - 2s/epoch - 19ms/step
# Epoch 128/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0666 - 2s/epoch - 19ms/step
# Epoch 129/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0757 - 2s/epoch - 18ms/step
# Epoch 130/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 17ms/step
# Epoch 131/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0712 - 2s/epoch - 18ms/step
# Epoch 132/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0724 - 2s/epoch - 17ms/step
# Epoch 133/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0728 - 2s/epoch - 17ms/step
# Epoch 134/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0702 - 2s/epoch - 17ms/step
# Epoch 135/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 17ms/step
# Epoch 136/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 18ms/step
# Epoch 137/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 17ms/step
# Epoch 138/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0693 - 2s/epoch - 18ms/step
# Epoch 139/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 18ms/step
# Epoch 140/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0720 - 2s/epoch - 18ms/step
# Epoch 141/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0702 - 2s/epoch - 17ms/step
# Epoch 142/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 17ms/step
# Epoch 143/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 17ms/step
# Epoch 144/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0681 - 2s/epoch - 17ms/step
# Epoch 145/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0676 - 2s/epoch - 17ms/step
# Epoch 146/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 18ms/step
# Epoch 147/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0754 - 2s/epoch - 18ms/step
# Epoch 148/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0706 - 2s/epoch - 17ms/step
# Epoch 149/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0726 - 2s/epoch - 17ms/step
# Epoch 150/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0692 - 2s/epoch - 17ms/step
# Epoch 151/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0668 - 2s/epoch - 18ms/step
# Epoch 152/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0752 - 2s/epoch - 18ms/step
# Epoch 153/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0754 - 2s/epoch - 18ms/step
# Epoch 154/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0731 - 2s/epoch - 18ms/step
# Epoch 155/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0717 - 2s/epoch - 17ms/step
# Epoch 156/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0718 - 2s/epoch - 18ms/step
# Epoch 157/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0717 - 2s/epoch - 18ms/step
# Epoch 158/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0717 - 2s/epoch - 19ms/step
# Epoch 159/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0714 - 2s/epoch - 18ms/step
# Epoch 160/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0728 - 2s/epoch - 18ms/step
# Epoch 161/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0691 - 2s/epoch - 19ms/step
# Epoch 162/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 18ms/step
# Epoch 163/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0675 - 2s/epoch - 18ms/step
# Epoch 164/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0752 - 2s/epoch - 18ms/step
# Epoch 165/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0677 - 2s/epoch - 18ms/step
# Epoch 166/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0716 - 2s/epoch - 18ms/step
# Epoch 167/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0721 - 2s/epoch - 18ms/step
# Epoch 168/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0710 - 2s/epoch - 18ms/step
# Epoch 169/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0758 - 2s/epoch - 18ms/step
# Epoch 170/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0721 - 2s/epoch - 18ms/step
# Epoch 171/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0725 - 2s/epoch - 18ms/step
# Epoch 172/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 17ms/step
# Epoch 173/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0686 - 2s/epoch - 17ms/step
# Epoch 174/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0687 - 2s/epoch - 19ms/step
# Epoch 175/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0731 - 2s/epoch - 19ms/step
# Epoch 176/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0726 - 2s/epoch - 18ms/step
# Epoch 177/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0685 - 2s/epoch - 19ms/step
# Epoch 178/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0679 - 2s/epoch - 18ms/step
# Epoch 179/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0737 - 2s/epoch - 18ms/step
# Epoch 180/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0669 - 2s/epoch - 18ms/step
# Epoch 181/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0699 - 2s/epoch - 18ms/step
# Epoch 182/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0691 - 2s/epoch - 18ms/step
# Epoch 183/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 18ms/step
# Epoch 184/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0691 - 2s/epoch - 18ms/step
# Epoch 185/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0704 - 2s/epoch - 18ms/step
# Epoch 186/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0715 - 2s/epoch - 18ms/step
# Epoch 187/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0710 - 2s/epoch - 18ms/step
# Epoch 188/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0719 - 2s/epoch - 18ms/step
# Epoch 189/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0727 - 2s/epoch - 18ms/step
# Epoch 190/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0686 - 2s/epoch - 18ms/step
# Epoch 191/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0717 - 2s/epoch - 17ms/step
# Epoch 192/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0747 - 2s/epoch - 18ms/step
# Epoch 193/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0744 - 2s/epoch - 18ms/step
# Epoch 194/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0714 - 2s/epoch - 18ms/step
# Epoch 195/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0728 - 2s/epoch - 18ms/step
# Epoch 196/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 18ms/step
# Epoch 197/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0697 - 2s/epoch - 18ms/step
# Epoch 198/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0743 - 2s/epoch - 18ms/step
# Epoch 199/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 18ms/step
# Epoch 200/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0764 - 2s/epoch - 18ms/step
# Epoch 201/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0686 - 2s/epoch - 18ms/step
# Epoch 202/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0717 - 2s/epoch - 18ms/step
# Epoch 203/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0721 - 2s/epoch - 19ms/step
# Epoch 204/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0717 - 2s/epoch - 18ms/step
# Epoch 205/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 18ms/step
# Epoch 206/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0700 - 2s/epoch - 19ms/step
# Epoch 207/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 18ms/step
# Epoch 208/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 18ms/step
# Epoch 209/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0737 - 2s/epoch - 18ms/step
# Epoch 210/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0706 - 2s/epoch - 18ms/step
# Epoch 211/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0696 - 2s/epoch - 18ms/step
# Epoch 212/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0746 - 2s/epoch - 19ms/step
# Epoch 213/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0693 - 2s/epoch - 18ms/step
# Epoch 214/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0716 - 2s/epoch - 18ms/step
# Epoch 215/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0696 - 2s/epoch - 18ms/step
# Epoch 216/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0712 - 2s/epoch - 18ms/step
# Epoch 217/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 18ms/step
# Epoch 218/1500
# 100/100 - 2s - loss: 0.0024 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0779 - 2s/epoch - 18ms/step
# Epoch 219/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 19ms/step
# Epoch 220/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0716 - 2s/epoch - 18ms/step
# Epoch 221/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0718 - 2s/epoch - 18ms/step
# Epoch 222/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0710 - 2s/epoch - 18ms/step
# Epoch 223/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0715 - 2s/epoch - 18ms/step
# Epoch 224/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0733 - 2s/epoch - 18ms/step
# Epoch 225/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0723 - 2s/epoch - 18ms/step
# Epoch 226/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0738 - 2s/epoch - 17ms/step
# Epoch 227/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0693 - 2s/epoch - 18ms/step
# Epoch 228/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0692 - 2s/epoch - 18ms/step
# Epoch 229/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0726 - 2s/epoch - 19ms/step
# Epoch 230/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0680 - 2s/epoch - 19ms/step
# Epoch 231/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0710 - 2s/epoch - 19ms/step
# Epoch 232/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0706 - 2s/epoch - 18ms/step
# Epoch 233/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0757 - 2s/epoch - 19ms/step
# Epoch 234/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0688 - 2s/epoch - 18ms/step
# Epoch 235/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0769 - 2s/epoch - 18ms/step
# Epoch 236/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0704 - 2s/epoch - 18ms/step
# Epoch 237/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0697 - 2s/epoch - 18ms/step
# Epoch 238/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0765 - 2s/epoch - 18ms/step
# Epoch 239/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0714 - 2s/epoch - 18ms/step
# Epoch 240/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0735 - 2s/epoch - 19ms/step
# Epoch 241/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0727 - 2s/epoch - 18ms/step
# Epoch 242/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 18ms/step
# Epoch 243/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0711 - 2s/epoch - 18ms/step
# Epoch 244/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0733 - 2s/epoch - 18ms/step
# Epoch 245/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 17ms/step
# Epoch 246/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0712 - 2s/epoch - 18ms/step
# Epoch 247/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0731 - 2s/epoch - 18ms/step
# Epoch 248/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0731 - 2s/epoch - 18ms/step
# Epoch 249/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0726 - 2s/epoch - 18ms/step
# Epoch 250/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0751 - 2s/epoch - 19ms/step
# Epoch 251/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0726 - 2s/epoch - 18ms/step
# Epoch 252/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 18ms/step
# Epoch 253/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0722 - 2s/epoch - 18ms/step
# Epoch 254/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 18ms/step
# Epoch 255/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0665 - 2s/epoch - 18ms/step
# Epoch 256/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0665 - 2s/epoch - 18ms/step
# Epoch 257/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0678 - 2s/epoch - 18ms/step
# Epoch 258/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0683 - 2s/epoch - 18ms/step
# Epoch 259/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0742 - 2s/epoch - 18ms/step
# Epoch 260/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0704 - 2s/epoch - 18ms/step
# Epoch 261/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0719 - 2s/epoch - 16ms/step
# Epoch 262/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0722 - 2s/epoch - 18ms/step
# Epoch 263/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0727 - 2s/epoch - 18ms/step
# Epoch 264/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0752 - 2s/epoch - 18ms/step
# Epoch 265/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0720 - 2s/epoch - 18ms/step
# Epoch 266/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0714 - 2s/epoch - 18ms/step
# Epoch 267/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0730 - 2s/epoch - 18ms/step
# Epoch 268/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0676 - 2s/epoch - 18ms/step
# Epoch 269/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0728 - 2s/epoch - 19ms/step
# Epoch 270/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0752 - 2s/epoch - 18ms/step
# Epoch 271/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0735 - 2s/epoch - 18ms/step
# Epoch 272/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0718 - 2s/epoch - 18ms/step
# Epoch 273/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0740 - 2s/epoch - 18ms/step
# Epoch 274/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0713 - 2s/epoch - 18ms/step
# Epoch 275/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0729 - 2s/epoch - 18ms/step
# Epoch 276/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0713 - 2s/epoch - 18ms/step
# Epoch 277/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0673 - 2s/epoch - 18ms/step
# Epoch 278/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0712 - 2s/epoch - 18ms/step
# Epoch 279/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0713 - 2s/epoch - 18ms/step
# Epoch 280/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0763 - 2s/epoch - 18ms/step
# Epoch 281/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0712 - 2s/epoch - 18ms/step
# Epoch 282/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0721 - 2s/epoch - 19ms/step
# Epoch 283/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0704 - 2s/epoch - 18ms/step
# Epoch 284/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0716 - 2s/epoch - 19ms/step
# Epoch 285/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0716 - 2s/epoch - 18ms/step
# Epoch 286/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 19ms/step
# Epoch 287/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0689 - 2s/epoch - 19ms/step
# Epoch 288/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0719 - 2s/epoch - 19ms/step
# Epoch 289/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0743 - 2s/epoch - 19ms/step
# Epoch 290/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0718 - 2s/epoch - 18ms/step
# Epoch 291/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0727 - 2s/epoch - 18ms/step
# Epoch 292/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0727 - 2s/epoch - 19ms/step
# Epoch 293/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0712 - 2s/epoch - 18ms/step
# Epoch 294/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 17ms/step
# Epoch 295/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0684 - 2s/epoch - 18ms/step
# Epoch 296/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0739 - 2s/epoch - 19ms/step
# Epoch 297/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0728 - 2s/epoch - 18ms/step
# Epoch 298/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0723 - 2s/epoch - 19ms/step
# Epoch 299/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0728 - 2s/epoch - 17ms/step
# Epoch 300/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 18ms/step
# Epoch 301/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0711 - 2s/epoch - 17ms/step
# Epoch 302/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0691 - 2s/epoch - 18ms/step
# Epoch 303/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0697 - 2s/epoch - 19ms/step
# Epoch 304/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 18ms/step
# Epoch 305/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0721 - 2s/epoch - 18ms/step
# Epoch 306/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0726 - 2s/epoch - 19ms/step
# Epoch 307/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0755 - 2s/epoch - 18ms/step
# Epoch 308/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0675 - 2s/epoch - 18ms/step
# Epoch 309/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0708 - 2s/epoch - 18ms/step
# Epoch 310/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0672 - 2s/epoch - 18ms/step
# Epoch 311/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0729 - 2s/epoch - 18ms/step
# Epoch 312/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0756 - 2s/epoch - 18ms/step
# Epoch 313/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0720 - 2s/epoch - 18ms/step
# Epoch 314/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0752 - 2s/epoch - 18ms/step
# Epoch 315/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0738 - 2s/epoch - 18ms/step
# Epoch 316/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0688 - 2s/epoch - 18ms/step
# Epoch 317/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0721 - 2s/epoch - 18ms/step
# Epoch 318/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0691 - 2s/epoch - 17ms/step
# Epoch 319/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0692 - 2s/epoch - 18ms/step
# Epoch 320/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0740 - 2s/epoch - 19ms/step
# Epoch 321/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0710 - 2s/epoch - 19ms/step
# Epoch 322/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0742 - 2s/epoch - 18ms/step
# Epoch 323/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0691 - 2s/epoch - 18ms/step
# Epoch 324/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0719 - 2s/epoch - 18ms/step
# Epoch 325/1500
# 100/100 - 2s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0740 - 2s/epoch - 19ms/step
# Epoch 326/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0740 - 2s/epoch - 17ms/step
# Epoch 327/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0740 - 2s/epoch - 17ms/step
# Epoch 328/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0702 - 2s/epoch - 18ms/step
# Epoch 329/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0710 - 2s/epoch - 18ms/step
# Epoch 330/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0747 - 2s/epoch - 18ms/step
# Epoch 331/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0696 - 2s/epoch - 17ms/step
# Epoch 332/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0719 - 2s/epoch - 17ms/step
# Epoch 333/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0699 - 2s/epoch - 18ms/step
# Epoch 334/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0682 - 2s/epoch - 20ms/step
# Epoch 335/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0728 - 2s/epoch - 19ms/step
# Epoch 336/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0686 - 2s/epoch - 19ms/step
# Epoch 337/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 19ms/step
# Epoch 338/1500
# 100/100 - 2s - loss: 0.0023 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0754 - 2s/epoch - 19ms/step
# Epoch 339/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0723 - 2s/epoch - 18ms/step
# Epoch 340/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0724 - 2s/epoch - 17ms/step
# Epoch 341/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0736 - 2s/epoch - 18ms/step
# Epoch 342/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0722 - 2s/epoch - 18ms/step
# Epoch 343/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0715 - 2s/epoch - 18ms/step
# Epoch 344/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0731 - 2s/epoch - 18ms/step
# Epoch 345/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0716 - 2s/epoch - 18ms/step
# Epoch 346/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0692 - 2s/epoch - 18ms/step
# Epoch 347/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0720 - 2s/epoch - 19ms/step
# Epoch 348/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0727 - 2s/epoch - 20ms/step
# Epoch 349/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0717 - 2s/epoch - 19ms/step
# Epoch 350/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0706 - 2s/epoch - 18ms/step
# Epoch 351/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0695 - 2s/epoch - 19ms/step
# Epoch 352/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0719 - 2s/epoch - 18ms/step
# Epoch 353/1500
# 100/100 - 2s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0711 - 2s/epoch - 19ms/step
# Epoch 354/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0719 - 2s/epoch - 20ms/step
# Epoch 355/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0708 - 2s/epoch - 19ms/step
# Epoch 356/1500
# 100/100 - 2s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0700 - 2s/epoch - 19ms/step
# Epoch 357/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0688 - 2s/epoch - 18ms/step
# Epoch 358/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 19ms/step
# Epoch 359/1500
# ...
# Epoch 1383/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 17ms/step
# Epoch 1384/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0718 - 2s/epoch - 18ms/step
# Epoch 1385/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0689 - 2s/epoch - 18ms/step
# Epoch 1386/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0682 - 2s/epoch - 18ms/step
# Epoch 1387/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 17ms/step
# Epoch 1388/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0678 - 2s/epoch - 18ms/step
# Epoch 1389/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0685 - 2s/epoch - 17ms/step
# Epoch 1390/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0696 - 2s/epoch - 17ms/step
# Epoch 1391/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0716 - 2s/epoch - 18ms/step
# Epoch 1392/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 17ms/step
# Epoch 1393/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 17ms/step
# Epoch 1394/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.7482e-04 - vxm_dense_flow_loss: 0.0680 - 2s/epoch - 18ms/step
# Epoch 1395/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0667 - 2s/epoch - 18ms/step
# Epoch 1396/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.5254e-04 - vxm_dense_flow_loss: 0.0665 - 2s/epoch - 17ms/step
# Epoch 1397/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0722 - 2s/epoch - 18ms/step
# Epoch 1398/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 17ms/step
# Epoch 1399/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0685 - 2s/epoch - 18ms/step
# Epoch 1400/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.6402e-04 - vxm_dense_flow_loss: 0.0673 - 2s/epoch - 18ms/step
# Epoch 1401/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0711 - 2s/epoch - 17ms/step
# Epoch 1402/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0710 - 2s/epoch - 17ms/step
# Epoch 1403/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.3681e-04 - vxm_dense_flow_loss: 0.0664 - 2s/epoch - 18ms/step
# Epoch 1404/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0671 - 2s/epoch - 17ms/step
# Epoch 1405/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0728 - 2s/epoch - 18ms/step
# Epoch 1406/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0678 - 2s/epoch - 17ms/step
# Epoch 1407/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0737 - 2s/epoch - 17ms/step
# Epoch 1408/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0747 - 2s/epoch - 17ms/step
# Epoch 1409/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0716 - 2s/epoch - 17ms/step
# Epoch 1410/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 18ms/step
# Epoch 1411/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0702 - 2s/epoch - 18ms/step
# Epoch 1412/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0717 - 2s/epoch - 18ms/step
# Epoch 1413/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0737 - 2s/epoch - 18ms/step
# Epoch 1414/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0717 - 2s/epoch - 17ms/step
# Epoch 1415/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0697 - 2s/epoch - 17ms/step
# Epoch 1416/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0727 - 2s/epoch - 18ms/step
# Epoch 1417/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0734 - 2s/epoch - 17ms/step
# Epoch 1418/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 17ms/step
# Epoch 1419/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.6209e-04 - vxm_dense_flow_loss: 0.0670 - 2s/epoch - 18ms/step
# Epoch 1420/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0689 - 2s/epoch - 18ms/step
# Epoch 1421/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0718 - 2s/epoch - 17ms/step
# Epoch 1422/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0710 - 2s/epoch - 17ms/step
# Epoch 1423/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0719 - 2s/epoch - 18ms/step
# Epoch 1424/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0708 - 2s/epoch - 18ms/step
# Epoch 1425/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 18ms/step
# Epoch 1426/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0668 - 2s/epoch - 18ms/step
# Epoch 1427/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0711 - 2s/epoch - 18ms/step
# Epoch 1428/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0718 - 2s/epoch - 18ms/step
# Epoch 1429/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 18ms/step
# Epoch 1430/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 18ms/step
# Epoch 1431/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0715 - 2s/epoch - 17ms/step
# Epoch 1432/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0693 - 2s/epoch - 17ms/step
# Epoch 1433/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.8501e-04 - vxm_dense_flow_loss: 0.0678 - 2s/epoch - 18ms/step
# Epoch 1434/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0702 - 2s/epoch - 17ms/step
# Epoch 1435/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0697 - 2s/epoch - 17ms/step
# Epoch 1436/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0716 - 2s/epoch - 18ms/step
# Epoch 1437/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0742 - 2s/epoch - 18ms/step
# Epoch 1438/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0740 - 2s/epoch - 17ms/step
# Epoch 1439/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0720 - 2s/epoch - 17ms/step
# Epoch 1440/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.5298e-04 - vxm_dense_flow_loss: 0.0676 - 2s/epoch - 17ms/step
# Epoch 1441/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0734 - 2s/epoch - 16ms/step
# Epoch 1442/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0726 - 2s/epoch - 18ms/step
# Epoch 1443/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0715 - 2s/epoch - 17ms/step
# Epoch 1444/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0713 - 2s/epoch - 17ms/step
# Epoch 1445/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.8679e-04 - vxm_dense_flow_loss: 0.0694 - 2s/epoch - 18ms/step
# Epoch 1446/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0700 - 2s/epoch - 18ms/step
# Epoch 1447/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.9158e-04 - vxm_dense_flow_loss: 0.0687 - 2s/epoch - 17ms/step
# Epoch 1448/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.9633e-04 - vxm_dense_flow_loss: 0.0675 - 2s/epoch - 17ms/step
# Epoch 1449/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0693 - 2s/epoch - 17ms/step
# Epoch 1450/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 17ms/step
# Epoch 1451/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0738 - 2s/epoch - 17ms/step
# Epoch 1452/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0696 - 2s/epoch - 17ms/step
# Epoch 1453/1500
# 100/100 - 2s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0760 - 2s/epoch - 17ms/step
# Epoch 1454/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0684 - 2s/epoch - 18ms/step
# Epoch 1455/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0743 - 2s/epoch - 17ms/step
# Epoch 1456/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.9536e-04 - vxm_dense_flow_loss: 0.0664 - 2s/epoch - 17ms/step
# Epoch 1457/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.8468e-04 - vxm_dense_flow_loss: 0.0685 - 2s/epoch - 18ms/step
# Epoch 1458/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0667 - 2s/epoch - 17ms/step
# Epoch 1459/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0714 - 2s/epoch - 17ms/step
# Epoch 1460/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0709 - 2s/epoch - 17ms/step
# Epoch 1461/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0734 - 2s/epoch - 18ms/step
# Epoch 1462/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0700 - 2s/epoch - 17ms/step
# Epoch 1463/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0715 - 2s/epoch - 17ms/step
# Epoch 1464/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.9502e-04 - vxm_dense_flow_loss: 0.0688 - 2s/epoch - 17ms/step
# Epoch 1465/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.9587e-04 - vxm_dense_flow_loss: 0.0676 - 2s/epoch - 17ms/step
# Epoch 1466/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0718 - 2s/epoch - 17ms/step
# Epoch 1467/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0706 - 2s/epoch - 17ms/step
# Epoch 1468/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 17ms/step
# Epoch 1469/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.7903e-04 - vxm_dense_flow_loss: 0.0665 - 2s/epoch - 17ms/step
# Epoch 1470/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 17ms/step
# Epoch 1471/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 17ms/step
# Epoch 1472/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0722 - 2s/epoch - 17ms/step
# Epoch 1473/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0703 - 2s/epoch - 17ms/step
# Epoch 1474/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 17ms/step
# Epoch 1475/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0692 - 2s/epoch - 18ms/step
# Epoch 1476/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0692 - 2s/epoch - 18ms/step
# Epoch 1477/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.7678e-04 - vxm_dense_flow_loss: 0.0662 - 2s/epoch - 17ms/step
# Epoch 1478/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0715 - 2s/epoch - 18ms/step
# Epoch 1479/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0726 - 2s/epoch - 17ms/step
# Epoch 1480/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.7486e-04 - vxm_dense_flow_loss: 0.0674 - 2s/epoch - 18ms/step
# Epoch 1481/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0707 - 2s/epoch - 17ms/step
# Epoch 1482/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.8690e-04 - vxm_dense_flow_loss: 0.0672 - 2s/epoch - 18ms/step
# Epoch 1483/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0712 - 2s/epoch - 17ms/step
# Epoch 1484/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0720 - 2s/epoch - 18ms/step
# Epoch 1485/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0701 - 2s/epoch - 17ms/step
# Epoch 1486/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.8364e-04 - vxm_dense_flow_loss: 0.0684 - 2s/epoch - 17ms/step
# Epoch 1487/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0681 - 2s/epoch - 17ms/step
# Epoch 1488/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.4804e-04 - vxm_dense_flow_loss: 0.0670 - 2s/epoch - 17ms/step
# Epoch 1489/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.5312e-04 - vxm_dense_flow_loss: 0.0672 - 2s/epoch - 17ms/step
# Epoch 1490/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0705 - 2s/epoch - 17ms/step
# Epoch 1491/1500
# 100/100 - 2s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0730 - 2s/epoch - 17ms/step
# Epoch 1492/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 9.9330e-04 - vxm_dense_flow_loss: 0.0687 - 2s/epoch - 18ms/step
# Epoch 1493/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0706 - 2s/epoch - 18ms/step
# Epoch 1494/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0683 - 2s/epoch - 18ms/step
# Epoch 1495/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0692 - 2s/epoch - 18ms/step
# Epoch 1496/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0713 - 2s/epoch - 17ms/step
# Epoch 1497/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0698 - 2s/epoch - 17ms/step
# Epoch 1498/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0693 - 2s/epoch - 17ms/step
# Epoch 1499/1500
# 100/100 - 2s - loss: 0.0016 - vxm_dense_transformer_loss: 9.5079e-04 - vxm_dense_flow_loss: 0.0673 - 2s/epoch - 17ms/step
# Epoch 1500/1500
# 100/100 - 2s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0699 - 2s/epoch - 17ms/step

# %%
# as before, let's visualize what happened
plot_history(hist)

# %% [markdown]
# We ran very few epochs for the purpose of the tutorial. Of course, we do not except any sort of reasonable convergence here. Let's load a model pretrained for 200 epochs:

# %%
# # load pretrained model weights
# vxm_model.load_weights('brain_2d_smooth.h5')

# %% [markdown]
# Now let's see some results using validation data...

# %%
# create the validation data generator
val_generator = vxm_data_generator(x_val, batch_size = 1)
val_input, _ = next(val_generator)

# %%
# prediction
val_pred = vxm_model.predict(val_input)
# Out:
# 1/1 [==============================] - 0s 454ms/step

# %%
# visualize registration
images = [img[0, :, :, 0] for img in val_input + val_pred] 
titles = ['moving', 'fixed', 'moved', 'flow']
ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %%
# visualize flow
flow = val_pred[1].squeeze()[::3,::3]
ne.plot.flow([flow], width=5);

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluating registration results is tricky. The first tendancy is to look at the images (as above), and conclude that if they match, The registration has succeeded.
#
# However, this can be achieved by an optimization that only penalizes the image matching term. For example, next we compare our model with one that was trained on maximizing MSE only (without smoothness loss).

# %%
# # prediction from model with MSE + smoothness loss
# vxm_model.load_weights('brain_2d_smooth.h5')
our_val_pred = vxm_model.predict(val_input)

# # prediction from model with just MSE loss
# vxm_model.load_weights('brain_2d_no_smooth.h5')
# mse_val_pred = vxm_model.predict(val_input)
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
# # visualize MSE + smoothness model output
# images = [img[0, ..., 0] for img in [val_input[1], *our_val_pred]]
# titles = ['fixed', 'MSE + smoothness', 'flow']
# ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# # visualize MSE model output
# images = [img[0, ..., 0] for img in [val_input[1], *mse_val_pred]]
# titles = ['fixed', 'MSE only', 'flow']
# ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %%
ne.plot.flow([img[1].squeeze()[::3, ::3] for img in [our_val_pred]], width=10);

# %% [markdown]
# At first look, the MSE-only model matches the fixed image better, but we can see that it obtains a deformation field that is very noisy, unlikely to be anatomically meaningful.
#
# What we often do isntead of use **external anotations** for evaluation one way is using anatomical segmentations.
#
# In the next section, we demonstrate the use of a 3D model, and show how to evaluate it with segmentations.

# %% [markdown]
# # 3D MRI brain scan registration

# %% [markdown]
# Finally, we get to 3D models, which are of particular interest in medical image analysis.
#
# However, due to the size of the models and data, we won't be able to train a model within a short tutorial time. Instead, here we assume one has been trained, and demonstrate its use. You can train one very similar to how you trained the 2D models above.

# %% [markdown]
# ### Model

# %%
# # our data will be of shape 160 x 192 x 224
# vol_shape = (160, 192, 224)
# nb_features = [
#     [16, 32, 32, 32],
#     [32, 32, 32, 32, 32, 16, 16]
# ]

# %%
# # build vxm network
# vxm_model = vxm.networks.VxmDense(vol_shape, nb_features, int_steps=0);

# %% [markdown]
# ### Validation data

# %% [markdown]
# Let's prepare our validation data.

# %%
# val_volume_1 = np.load('subj1.npz')['vol']
# seg_volume_1 = np.load('subj1.npz')['seg']
# val_volume_2 = np.load('subj2.npz')['vol']
# seg_volume_2 = np.load('subj2.npz')['seg']

# val_input = [
#     val_volume_1[np.newaxis, ..., np.newaxis],
#     val_volume_2[np.newaxis, ..., np.newaxis]
# ]

# %% [markdown]
# Load a trained 3D model.

# %%
# vxm_model.load_weights('brain_3d.h5')

# %% [markdown]
# Now let's register.

# %%
# val_pred = vxm_model.predict(val_input);

# %%
# moved_pred = val_pred[0].squeeze()
# pred_warp = val_pred[1]

# %%
# mid_slices_fixed = [np.take(val_volume_2, vol_shape[d]//2, axis=d) for d in range(3)]
# mid_slices_fixed[1] = np.rot90(mid_slices_fixed[1], 1)
# mid_slices_fixed[2] = np.rot90(mid_slices_fixed[2], -1)

# mid_slices_pred = [np.take(moved_pred, vol_shape[d]//2, axis=d) for d in range(3)]
# mid_slices_pred[1] = np.rot90(mid_slices_pred[1], 1)
# mid_slices_pred[2] = np.rot90(mid_slices_pred[2], -1)
# ne.plot.slices(mid_slices_fixed + mid_slices_pred, cmaps=['gray'], do_colorbars=True, grid=[2,3]);

# %% [markdown]
# Let's look at the segmentations! To do this, we'll need to warp segmentations.

# %%
# warp_model = vxm.networks.Transform(vol_shape, interp_method='nearest')

# %%
# warped_seg = warp_model.predict([seg_volume_1[np.newaxis,...,np.newaxis], pred_warp])

# %% [markdown]
# We're first going to prepare a colormap.

# %%
# from pystrum.pytools.plot import jitter
# import matplotlib

# [ccmap, scrambled_cmap] = jitter(255, nargout=2)
# scrambled_cmap[0, :] = np.array([0, 0, 0, 1])
# ccmap = matplotlib.colors.ListedColormap(scrambled_cmap)

# %% [markdown]
# Let's visualize the segmentations, and essentially make sure they are not crazy.

# %%
# mid_slices_fixed = [np.take(seg_volume_1, vol_shape[d]//1.8, axis=d) for d in range(3)]
# mid_slices_fixed[1] = np.rot90(mid_slices_fixed[1], 1)
# mid_slices_fixed[2] = np.rot90(mid_slices_fixed[2], -1)

# mid_slices_pred = [np.take(warped_seg.squeeze(), vol_shape[d]//1.8, axis=d) for d in range(3)]
# mid_slices_pred[1] = np.rot90(mid_slices_pred[1], 1)
# mid_slices_pred[2] = np.rot90(mid_slices_pred[2], -1)

# slices = mid_slices_fixed + mid_slices_pred
# for si, slc  in enumerate(slices):
#     slices[si][0] = 255
# ne.plot.slices(slices, cmaps = [ccmap], grid=[2,3]);

# %% [markdown]
# ## Runtime

# %% [markdown]
# An important advantage of learning-based methods is the dramatically lowered runtime.

# %%
# %timeit vxm_model.predict(val_input)

# %% [markdown]
# In our tests, a run is 10s, for an entire 3D volume. Classically, this would take hours.
